# %% [markdown]
# # Assignment 1
# Matthew Koh
# OPIM 5641 - Business Decision Modeling
# 9/20/2026 10:59 PM 😭

# %% [markdown]
# ## Dataset: FronkonGames, "Steam Games Dataset" (Kaggle/Hugging Face)
# snapshot 2026-08-01, accessed 2026-08-04
# cleaned by Matthew Koh for OPIM 5501 Visual Analytics, Project 2, Group 7 (Summer 2026)
#
# the dataset's reviews for new games drops off in May 2025, because at the time of the snapshot reviews were not yet populated. so I cut the dataset there.

# %% [markdown]
# ## AI assist
# used Claude to structure work distribution, analysis, choices, and interpretation will be mine

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/mkoh55/opim5641-work/main/Assignment%201/steam_clean_master.csv'
df = pd.read_csv(url)
print(df.shape)
df.head(3)
# Out:
# (93432, 38)
#      AppID                                   Name ReleaseDate  ReleaseYear  \
# 0   496350  Supipara - Chapter 1 Spring Has Come!  2016-07-29         2016
# 1  1034400      Mystery Solitaire The Black Raven  2019-05-06         2019
# 2  3292190            버튜버 파라노이아 - Vtuber Paranoia  2024-10-31         2024
#
#    Price  Discount  DLCCount  RequiredAge EstimatedOwners  OwnersMin  ...  \
# 0   5.24        65         0            0       0 - 20000          0  ...
# 1   4.99         0         0            0       0 - 20000          0  ...
# 2   8.99         0         1            0       0 - 20000          0  ...
#
#    PublisherCount                   Genres  GenreCount  \
# 0               1                Adventure           1
# 1               1                   Casual           1
# 2               1  Casual;Indie;Simulation           3
#
#                                           Categories     TopTag  TopTagVotes  \
# ...

# %% [markdown]
# ## Initial Description

# %%
pd.set_option('display.float_format', '{:,.2f}'.format)

# %%
df[['Price','TotalReviews']].describe()
# Out:
#           Price  TotalReviews
# count 93,432.00     93,432.00
# mean       5.13      1,583.92
# std       12.00     37,373.84
# min        0.00          0.00
# 25%        0.99          3.00
# 50%        2.99         17.00
# 75%        5.99         93.00
# max      999.98  8,815,087.00

# %% [markdown]
# ## Initial Description finding
# both price and review are right skewed
# review count is VERY right skewed - median game has 17 reviews, mean is 1,584
#
# can't summarize this column with average, normal distribution model won't work for anything built on the reviews problem. taking the log of totalreviews can help

# %% [markdown]
# ## Log 10 Histogram

# %%
import numpy as np

reviewed = df[df['TotalReviews'] > 0]['TotalReviews'] # (np.log10(0) is negative infinity)
print(f'lots of games on steam have no reviews. {(df["TotalReviews"] == 0).sum():,} games had no reviews, dropped')

plt.figure(figsize=(9, 4))
plt.hist(np.log10(reviewed), bins=40) # 10 bins isn't enough to see the crazy tail


plt.axvline(np.log10(reviewed.median()), 
            color='red', 
            linestyle='dashed', 
            label=f'median {reviewed.median():,.0f} reviews')
plt.axvline(np.log10(reviewed.mean()), 
            color='darkorange', 
            linestyle='dashed', 
            label=f'mean {reviewed.mean():,.0f} reviews')

plt.legend()
plt.title('Steam reviews per game (log10 scale) - mean is hella dragged towards right')
plt.xlabel('log10(TotalReviews)')
plt.ylabel('# of games')

plt.savefig('fig1.png')
# Out:
# lots of games on steam have no reviews. 10,993 games had no reviews, dropped

# %% [markdown]
#  ## log(10) Histogram findings
# typical reviewed game has 23 reviews, while mean of 1795 is almost 100x that
#
# 2% of the dataset has >10k reviews: 2% of the dataset has more reviews than the other 98%

# %%
counts = df['ReleaseYear'].value_counts().sort_index()#.plot(kind='bar') # order by index sorts by time, don't want to sort by count
colors = ['lightgray' if year == 2025 else 'steelblue' for year in counts.index]

plt.bar(counts.index, counts.values, color=colors)
plt.title('Steam releases per year: 10x more games in 2024 than in 2014')
plt.xlabel('release year')
plt.ylabel('number of games')
# Out:
# Text(0, 0.5, 'number of games')

# %% [markdown]
# ## Bar chart finding
# release crowding exploded around 2014, 2025 is partial for the reason explained at the top
#
# flood of supply is the life of an indie game dev. good luck getting enough reviews to even get rated

# %% [markdown]
# ## FRED (Federal Reserve Economic Data): Free public db
# https://fred.stlouisfed.org/

# %%
# cpi = pd.read_csv('https://fred.stlouisfed.org/graph/fredgraph.csv?id=CPIAUCSL')
# cpi.columns = ['date','cpi']
# # print(cpi.describe())
# cpi['year'] = pd.to_datetime(cpi['date']).dt.year
# annual = cpi.groupby('year')['cpi'].mean().reset_index()
# base = annual.loc[annual.year==2025,'cpi'].values[0]
# annual['deflator'] = base / annual['cpi']
# df = df.merge(annual[['year','deflator']], left_on='ReleaseYear', right_on='year', how='left') # only works once, reset to rerun
# df['RealPrice'] = df['Price'] * df['deflator']

# %% [markdown]
# ## probably not worth pursuing
# deflating by releaseyear assumes price is what the game cost when it launched, when I don't think that's the case here. trying to deflate a 2015 game's price in 2025 shouldn't produce anything that makes sense

# %% [markdown]
# # **Everything after this point was done after submission deadline**

# %%
import requests, io
url = 'https://en.wikipedia.org/wiki/List_of_best-selling_PC_games'
response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0 (OPIM 5641 student project)'}) 
# print(response.status_code) # 200, nice
tables = pd.read_html(io.StringIO(response.text))
# for i, t in enumerate(tables): print(i, list(t.columns)[:4]) # table where
wiki = tables[1]
wiki['WikiSalesM'] = wiki['Total copies sold'].str.extract(r'([\d.]+)').astype(float)

# clean and parse

def clean(s):
    return (s.str.replace('™','', regex=False).str.replace('®','', regex=False)
            .str.strip().str.lower())
tmp = df[['Name','TotalReviews']].copy()
tmp['key'] = clean(tmp['Name'])
wiki['key'] = clean(wiki['Game'].astype(str))
# print('uhh: ', wiki)# nice

# parse merge and match and join n allat
foundMatch = tmp.merge(wiki[['key','WikiSalesM']], on='key', how='inner')
foundMatch['EstUnitsM'] = foundMatch['TotalReviews'] * 30 / 1e6   # boxleiter estimate
foundMatch['ratio'] = foundMatch['EstUnitsM'] / foundMatch['WikiSalesM']
print(len(foundMatch), 'titles foundMatch') # sick
foundMatch.sort_values('WikiSalesM', ascending=False).head(15)
# Out:
# 171 titles foundMatch
#                          Name  TotalReviews                       key  \
# 13        PUBG: BATTLEGROUNDS       2557944       pubg: battlegrounds
# 16                   Terraria       1409473                  terraria
# 138            Stardew Valley        886195            stardew valley
# 49                Garry's Mod       1159707               garry's mod
# 0      Euro Truck Simulator 2        867404    euro truck simulator 2
# 65               Phasmophobia        768779              phasmophobia
# 7                        Rust       1227784                      rust
# 142    Counter-Strike: Source        182234    counter-strike: source
# 95              HELLDIVERS™ 2       1017635              helldivers 2
# 71                Half-Life 2        245627               half-life 2
# 55   The Witcher 3: Wild Hunt        835349  the witcher 3: wild hunt
# 167                   Valheim        499828                   valheim
# ...

# %% [markdown]
# something's wrong with peak, probably matched to a different peak

# %%
foundMatch = foundMatch.sort_values('TotalReviews', ascending=False).drop_duplicates('key')

real = foundMatch[foundMatch['TotalReviews'] >= 1000]
print(len(foundMatch) - len(real), 'name collisions dropped,', len(real), 'titles kept')
print(f"median ratio (estimate / reported): {real['ratio'].median():.2f}")
# Out:
# 13 name collisions dropped, 153 titles kept
# median ratio (estimate / reported): 1.10

# %%
plt.figure(figsize=(6, 6))
plt.scatter(real['WikiSalesM'], real['EstUnitsM'], alpha=0.6)
plt.plot([1, 100], [1, 100], color='red', linestyle='dashed', label='estimate = reported')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Wikipedia reported PC sales (millions)')
plt.ylabel('reviews x 30 estimate (millions)')
plt.title('Does the x30 Boxleiter multiplier hold up against reported sales?')
plt.legend()

# %% [markdown]
# Across 153 best matched best sellers, the 30x estimate lands at a median 1.1x of wikipedia's reported sales. this is probably close for big games.
#
# misses have known causes like how f2p games overshoot, and pre 2015 games were curated and undershoot. this checks sellers in the millions rather than indies

# %% [markdown]
# ## Business Framing Decision:
# ### A small publisher decides to fund 6 premium indie titles at 150k each, totaling 900k.
#
# ## **How likely is it for a given slate to fail to earn it back?**

# %%
slate_pool = df[ df['Genres'].fillna('').str.contains('Indie') & (df['Price'] >= 10) & df['ReleaseYear'].between(2020, 2024) ].copy()
# indie only
# exclude f2p
# exclude 2025, focus on when market was already crowded
print(len(slate_pool)) # how many non f2p indie titles were there between 2020 and 2024
# Out:
# 3426

# %% [markdown]
# ## Assumptions
#
# Big thing: Steam publishes review counts, Steam doesn't publish sales.
# As a result, to approximate a titles lifetime net revenue:
# reviews * 30 * game price * 70%
#
# 30: the Boxleiter multiplier: converts reviews to copies sold. GameDiscoverCo's survey had a median of 30 for recent releases as of 2021
#
# game price: uses price at scrape time, which is often a rough estimate for avg selling price as opposed to launch price
#
# 70%: steam takes 30%, cest la vie. revenue then equals 70% of (gross dollars)

# %%
slate_pool['NetRev'] = slate_pool['TotalReviews'] * 30 * slate_pool['Price'] * 0.70
slate_pool['NetRev'].describe()
# Out:
# count         3,426.00
# mean        930,745.57
# std       8,720,887.12
# min               0.00
# 25%           1,259.16
# 50%           8,395.80
# 75%          75,596.22
# max     225,859,582.41
# Name: NetRev, dtype: float64

# %% [markdown]
# # Simulate

# %%
np.random.seed(5641) #yep
n_sims, n_titles, budget = 10_000, 6, 900_000

revenues = []
profits = []
for sim in range(n_sims):
    slate = slate_pool['NetRev'].sample(n=n_titles, replace=True).values  # fund 6 random titles
    revenues.append(slate.sum())
    profits.append(slate.sum() - budget) # rev - spend

revenues = np.array(revenues)         # arrays for math reasons
profits = np.array(profits)

# %%
p5, p50, p95 = np.percentile(revenues, [5, 50, 95])   # the percentile lines

plt.hist(np.log10(revenues), bins=60, color='steelblue')   # log10 my beloved

for value, name, color in [(p5, '5th', 'gray'), (p50, 'median', 'red'), (p95, '95th', 'gray')]: plt.axvline(np.log10(value), color=color, linestyle='dashed', label=f'{name}: ${value:,.0f}')
plt.axvline(np.log10(budget), color='black', linewidth=2, label=f'break-even: ${budget:,.0f}')

plt.legend()
plt.title(f'10,000 simulated slates — P(loss) = {(profits < 0).mean():.1%}')
plt.xlabel('log10(slate net revenue $)   ·   4 = $10k · 5 = $100k · 6 = $1M · 7 = $10M')
plt.ylabel('number of slates')
# Out:
# Text(0, 0.5, 'number of slates')

# %%
print(f'Expected profit:  ${profits.mean():,.0f}')
print(f'Median profit:    ${np.median(profits):,.0f}')
print(f'P(loss):          {(profits < 0).mean():.1%}')
print(f'Max loss:         ${profits.min():,.0f}')
# Out:
# Expected profit:  $4,607,209
# Median profit:    $-303,454
# P(loss):          58.5%
# Max loss:         $-898,050

# %% [markdown]
# ### expected profit is >4mil
# ### yet most slates lose money
# # skewed data can't be accurately summarized just by average

# %%
mu = slate_pool['NetRev'].mean()
sd = slate_pool['NetRev'].std()

np.random.seed(5641) # reset
normal_profits = []
negative_titles = 0 # this bell curve  is so wide it produces negative revenue, which real games can't have
for sim in range(n_sims):
    slate = np.random.normal(mu, sd, n_titles)
    negative_titles += (slate < 0).sum()
    normal_profits.append(slate.sum() - budget)
normal_profits = np.array(normal_profits)

# %%
bins = np.linspace(-40, 40, 81)

plt.figure(figsize=(10, 4))
plt.hist(profits / 1e6, bins=bins, alpha=0.6, label='bootstrap: real titles')
plt.hist(normal_profits / 1e6, bins=bins, alpha=0.6, label='normal(mean, sd)')
plt.axvline(-budget / 1e6, color='black', linewidth=2, label='max real loss: -$0.9M')
plt.yscale('log')
plt.legend()
plt.title('The Normal model loses money that was never spent')
plt.xlabel('slate profit ($ millions)')
plt.ylabel('number of slates (log scale)')

# %%
print(f'{"":>10}  {"P(loss)":>8}  {"mean profit":>13}  {"median profit":>14}  {"worst case":>14}')
for name, p in [('bootstrap', profits), ('normal', normal_profits)]:
    print(f'{name:>10}  {(p < 0).mean():>8.1%}  ${p.mean():>12,.0f}  ${np.median(p):>13,.0f}  ${p.min():>13,.0f}')

print(f'\nNormal-drawn titles with negative revenue: {negative_titles / (n_sims * n_titles):.1%}')
print(f'Normal slates with negative TOTAL revenue: {((normal_profits + budget) < 0).mean():.1%}')
# Out:
#              P(loss)    mean profit   median profit      worst case
#  bootstrap     58.5%  $   4,607,209  $     -303,454  $     -898,050
#     normal     41.9%  $   4,608,078  $    4,358,836  $  -68,277,961
#
# Normal-drawn titles with negative revenue: 45.8%
# Normal slates with negative TOTAL revenue: 40.2%

# %%
np.random.seed(5641)
floored_profits = []
for sim in range(n_sims):
    slate = np.maximum(np.random.normal(mu, sd, n_titles), 0)   # floor impossible negatives at $0
    floored_profits.append(slate.sum() - budget)
floored_profits = np.array(floored_profits)
print(f'floored normal:  P(loss) {(floored_profits < 0).mean():.1%}   median profit ${np.median(floored_profits):,.0f}')
# Out:
# floored normal:  P(loss) 1.6%   median profit $21,385,795

# %% [markdown]
# ### Please don't fit a bell curve to data this skewed
#
# a normal distribution fitted to the same mean and standard deviation assumes the typical game earns 917,000 when games typically earn 8,400. Everything breaks.
#
# typical slates don't make 4.4 mil, they instead lose 303k.
#
# the normal model says P(loss) is 42%, when P(loss) is really 58.5%
#
# it invents negative revenue for 46% of games
#
# trying to floor the negatives makes things worse, and drops p(loss) to 1.6%.
#
# Please don't try to fit bell curves where they don't fit or work.
#
# bootstrap real titles, that makes no shape assumptions.

# %% [markdown]
# # Interpretation
# A publisher funding one 6 tile slate has a 58.5% chance of not earning back 900k
#
# median slate loses about 303k
#
# Expected profit is still +4.6mil beacuse rare breakout titles pay for everything: only a publisher that can fund many slates and survive the losing ones actually collect that average
#
# plan around the bootstrap

# %% [markdown]
# ### Limitations
# 30x is a range that was checked against best sellers - small games likely review at higher rates, as per how the Boxleiter number was defined
#
# lifetime reviews overstate what a publisher earns in a typical payback period
#
# 2020 had 5 years to collect reviews, 2024 had 1 year
#
# most of these errors inflate revenue, so the true P(loss) is likely higher than 58.5%
